# %%
import pandas as pd 

xx = pd.read_csv('/Users/pengsmac/Desktop/learning/AI工具学习/Claude code/model_monitor/data/model_data.csv')
xx.head()
# Out:
#    score     fea1     fea2     fea3  verify_time  label
# 0    493  59.5780  80.9423   5.8340   1769928870      0
# 1    626  69.0173  49.1385   2.8227   1769928959      1
# 2    672  43.8840  94.2313   8.6237   1769928992      0
# 3    764  56.1718  89.7259  28.0754   1769929017      1
# 4    462  27.8314  89.3178   4.2406   1769929042      0
